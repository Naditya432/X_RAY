# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8095493e-cff9-4544-8c03-f2352441c334" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8095493e-cff9-4544-8c03-f2352441c334">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"pythondevelopersr","key":"0d2d548e736e101512e38dd4a7124f33"}'}

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Copy the pneumonia data set locally.
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [00:26<00:00, 97.4MB/s]
# 100% 2.29G/2.29G [00:26<00:00, 92.1MB/s]

# %%
# Create directories
# !mkdir -p data/input
# !mkdir -p data/output

# %%
# !unzip -d data/input chest-xray-pneumonia.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/input/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0435-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0437-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0437-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0438-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0439-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0440-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0441-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0442-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0444-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0445-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0446-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0447-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0448-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0449-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0450-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0451-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0452-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0453-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0453-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0455-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0456-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0457-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0458-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0459-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0460-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0461-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0463-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0464-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0465-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0466-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0467-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0467-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0467-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0469-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0471-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0472-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0473-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0474-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0475-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0476-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0477-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0478-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0479-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0480-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0481-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0482-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0483-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0484-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0485-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0486-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0487-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0488-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0489-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0490-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0491-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0491-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0491-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0492-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0493-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0494-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0495-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0496-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0497-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0497-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0497-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0499-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0499-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0499-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0500-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0501-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0501-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0501-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0502-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0503-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0504-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0505-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0505-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0505-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0506-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0507-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0508-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0509-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0509-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0509-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0510-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0511-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0511-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0511-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0512-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0513-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0514-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0515-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0516-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0517-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0517-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0519-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0519-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0519-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0520-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0521-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0522-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0523-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0523-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0523-0001-0003.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0523-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0524-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0525-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0525-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0525-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0526-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0527-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0528-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0529-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0530-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0531-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0531-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0532-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0533-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0533-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0533-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0534-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0535-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0536-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0537-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0538-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0539-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0539-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0539-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0540-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0541-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0542-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0543-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0543-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0544-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0545-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0545-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0545-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0546-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0547-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0548-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0549-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0549-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0549-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0551-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0551-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0551-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0552-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0553-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0553-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0553-0001-0003.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0553-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0554-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0555-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0555-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0555-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0556-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0557-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0559-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0560-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0561-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0562-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0563-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0564-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0565-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0566-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0568-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0569-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0570-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0571-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0574-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0575-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0577-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0578-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0579-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0580-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0581-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0582-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0583-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0584-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0586-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0588-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0590-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0591-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0592-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0593-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0595-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0596-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0598-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0599-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0600-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0601-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0602-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0604-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0605-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0606-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0607-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0608-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0608-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0608-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0609-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0612-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0612-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0612-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0613-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0614-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0615-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0616-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0617-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0618-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0618-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0618-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0619-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0620-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0620-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0620-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0621-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0622-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0622-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0622-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0623-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0624-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0624-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0625-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0626-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0626-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0627-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0628-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0629-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0629-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0629-0001-0003.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0629-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0630-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0631-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0631-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0631-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0632-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0633-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0634-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0635-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0636-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0637-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0640-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0640-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0640-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0641-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0642-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0643-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0644-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0644-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0644-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0645-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0646-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0647-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0648-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0649-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0650-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0650-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0650-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0651-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0652-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0652-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0654-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0655-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0656-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0656-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0656-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0657-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0658-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0659-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0660-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0660-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0660-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0661-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0662-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0663-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0664-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0665-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0666-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0666-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0666-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0667-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0668-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0669-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0670-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0671-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0672-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0673-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0674-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0675-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0676-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0677-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0678-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0679-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0680-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0681-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0682-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0683-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0684-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0685-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0686-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0687-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0688-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0689-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0691-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0692-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0693-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0694-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0695-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0696-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0697-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0698-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0700-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0701-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0702-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0703-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0704-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0705-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0706-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0707-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0709-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0710-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0711-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0712-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0713-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0714-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0715-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0716-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0717-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0718-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0719-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0721-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0722-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0724-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0727-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0728-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0729-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0730-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0732-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0733-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0734-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0735-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0736-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0737-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0738-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0739-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0740-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0741-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0742-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0746-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0747-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0748-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0750-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0751-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0752-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0753-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0754-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0755-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0757-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0761-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0764-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/IM-0766-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0383-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0384-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0385-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0386-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0388-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0389-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0390-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0391-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0392-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0393-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0394-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0395-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0396-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0397-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0399-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0401-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0402-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0403-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0404-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0406-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0407-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0408-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0409-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0410-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0412-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0413-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0414-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0415-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0416-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0417-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0418-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0419-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0421-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0423-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0424-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0425-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0427-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0428-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0429-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0433-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0435-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0437-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0439-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0440-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0441-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0443-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0445-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0447-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0448-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0449-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0450-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0451-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0452-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0453-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0454-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0455-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0456-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0458-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0460-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0462-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0463-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0464-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0465-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0466-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0468-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0472-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0473-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0474-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0475-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0476-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0478-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0479-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0480-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0481-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0482-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0485-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0486-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0487-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0488-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0489-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0490-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0491-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0493-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0496-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0497-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0499-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0500-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0501-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0502-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0503-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0506-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0507-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0508-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0509-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0511-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0512-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0513-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0515-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0516-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0517-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0518-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0520-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0521-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0522-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0523-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0525-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0526-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0528-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0529-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0530-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0531-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0533-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0535-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0535-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0536-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0537-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0539-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0540-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0541-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0543-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0545-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0547-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0550-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0551-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0552-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0553-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0554-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0555-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0557-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0558-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0559-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0561-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0563-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0564-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0566-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0567-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0568-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0569-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0571-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0572-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0573-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0575-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0576-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0577-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0578-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0579-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0580-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0582-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0583-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0585-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0587-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0588-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0589-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0592-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0594-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0595-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0596-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0599-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0600-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0601-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0602-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0603-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0604-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0609-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0611-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0616-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0617-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0619-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0620-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0621-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0622-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0623-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0626-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0629-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0630-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0633-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0634-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0635-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0636-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0637-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0640-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0641-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0642-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0643-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0645-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0647-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0648-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0649-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0650-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0651-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0651-0004.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0652-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0653-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0654-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0655-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0657-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0659-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0660-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0661-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0662-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0663-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0664-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0665-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0666-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0667-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0668-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0669-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0671-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0672-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0673-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0675-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0678-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0680-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0682-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0683-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0684-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0686-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0687-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0689-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0690-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0692-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0693-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0694-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0695-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0696-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0698-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0699-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0700-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0702-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0705-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0707-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0718-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0719-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0723-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0725-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0727-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0730-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0736-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0741-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0744-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0746-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0749-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0753-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0757-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0765-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0771-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0772-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0774-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0775-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0776-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0777-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0780-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0781-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0790-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0793-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0796-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0797-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0798-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0799-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0803-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0804-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0806-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0807-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0808-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0809-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0810-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0811-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0812-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0814-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0815-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0816-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0818-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0819-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0820-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0821-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0822-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0824-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0825-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0826-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0827-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0828-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0829-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0830-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0831-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0001.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001-0002.jpeg
#   inflating: data/input/chest_xray/train/NORMAL/NORMAL2-IM-0832-0001.jpeg
# ...
#   inflating: data/input/chest_xray/train/PNEUMONIA/person900_virus_1554.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person901_virus_1555.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person902_bacteria_2827.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person903_bacteria_2828.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person904_bacteria_2829.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person905_bacteria_2830.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person905_virus_1561.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person906_bacteria_2831.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person906_virus_1562.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person907_bacteria_2832.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person907_virus_1563.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person908_virus_1564.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person909_bacteria_2834.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person909_virus_1565.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person90_virus_169.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person90_virus_170.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person911_bacteria_2836.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person911_virus_1567.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person912_bacteria_2837.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person913_bacteria_2838.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person913_virus_1570.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person914_bacteria_2839.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person914_virus_1571.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person915_virus_1572.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person916_bacteria_2841.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person917_bacteria_2842.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person918_bacteria_2843.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person918_virus_1575.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person919_bacteria_2844.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person919_virus_1576.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person920_bacteria_2845.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person920_virus_1577.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person921_bacteria_2846.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person921_virus_1578.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person922_bacteria_2847.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person923_bacteria_2848.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person924_bacteria_2849.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person924_virus_1581.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person925_bacteria_2850.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person925_virus_1582.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person926_virus_1583.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person927_bacteria_2852.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person927_virus_1584.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person928_virus_1586.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person929_bacteria_2854.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person929_virus_1588.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person929_virus_1589.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person92_virus_174.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person930_bacteria_2855.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person931_bacteria_2856.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person931_virus_1592.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person932_virus_1593.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person933_bacteria_2858.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person933_virus_1594.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person934_bacteria_2859.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person934_virus_1595.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person935_virus_1597.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person936_bacteria_2861.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person936_virus_1598.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person937_bacteria_2862.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person937_virus_1599.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person938_bacteria_2863.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person938_virus_1600.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person939_bacteria_2864.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person93_virus_175.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person940_bacteria_2865.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person940_virus_1602.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person940_virus_1604.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person940_virus_1605.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person940_virus_1607.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person940_virus_1609.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person941_virus_1610.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person942_bacteria_2867.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person942_virus_1611.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person943_bacteria_2868.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person944_bacteria_2869.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person945_bacteria_2870.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person945_virus_1616.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person946_bacteria_2871.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person947_bacteria_2872.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person947_virus_1618.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person949_bacteria_2874.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person949_virus_1620.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person94_virus_176.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person950_virus_1621.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person951_bacteria_2876.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person951_virus_1622.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person952_bacteria_2877.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person952_virus_1623.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person953_bacteria_2878.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person954_bacteria_2879.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person954_virus_1626.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person955_bacteria_2880.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person955_virus_1627.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person956_bacteria_2881.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person956_virus_1628.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person957_bacteria_2882.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person958_bacteria_2883.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person958_virus_1630.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person959_bacteria_2884.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person95_virus_177.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person960_bacteria_2885.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person960_virus_1633.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person961_bacteria_2886.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person961_virus_1634.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person962_bacteria_2887.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person962_virus_1635.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person963_bacteria_2888.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person963_virus_1636.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person964_bacteria_2889.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person964_virus_1637.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person965_bacteria_2890.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person965_virus_1638.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person966_bacteria_2891.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person966_virus_1639.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person967_bacteria_2892.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person967_virus_1640.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person968_bacteria_2893.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person968_virus_1642.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person969_bacteria_2894.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person969_virus_1643.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person96_virus_178.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person96_virus_179.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person970_bacteria_2895.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person970_virus_1644.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person971_bacteria_2896.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person972_bacteria_2897.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person972_virus_1646.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person973_virus_1647.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person974_bacteria_2899.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person974_virus_1649.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person975_virus_1650.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person976_bacteria_2901.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person976_virus_1651.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person977_bacteria_2902.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person977_virus_1652.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person978_bacteria_2904.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person978_virus_1653.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person979_bacteria_2905.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person979_virus_1654.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person97_virus_180.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person97_virus_181.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person980_bacteria_2906.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person980_virus_1655.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person981_bacteria_2907.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person981_bacteria_2908.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person981_virus_1657.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person982_bacteria_2909.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person982_virus_1658.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person983_bacteria_2910.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person983_virus_1660.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person984_bacteria_2911.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person985_bacteria_2912.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person986_bacteria_2913.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person987_bacteria_2914.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person988_bacteria_2915.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person988_virus_1666.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person989_virus_1667.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person98_virus_182.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person990_bacteria_2917.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person991_bacteria_2918.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person991_virus_1669.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person992_bacteria_2919.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person992_bacteria_2920.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person992_virus_1670.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person993_bacteria_2921.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person993_virus_1671.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person994_bacteria_2922.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person994_virus_1672.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person995_bacteria_2923.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person995_virus_1676.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person996_bacteria_2924.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person996_virus_1677.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person997_bacteria_2926.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person997_virus_1678.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person998_bacteria_2927.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person998_bacteria_2928.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person99_virus_183.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person9_bacteria_38.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person9_bacteria_39.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person9_bacteria_40.jpeg
#   inflating: data/input/chest_xray/train/PNEUMONIA/person9_bacteria_41.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1437-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1438-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg
#   inflating: data/input/chest_xray/val/NORMAL/NORMAL2-IM-1442-0001.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1946_bacteria_4875.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1947_bacteria_4876.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1949_bacteria_4880.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1950_bacteria_4881.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1951_bacteria_4882.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1952_bacteria_4883.jpeg
#   inflating: data/input/chest_xray/val/PNEUMONIA/person1954_bacteria_4886.jpeg

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from keras.preprocessing import image
import os
import matplotlib.pyplot as plt
import cv2
# Imports
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD, Adam
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau

from keras import backend as K
from sklearn.metrics import classification_report

import os
import random
import time
import re
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
import gc
import pathlib


from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report
from mlxtend.plotting import plot_confusion_matrix

# %%
# Creates directory, if directory exists removes if remove parameter is set to True 
def create_directory(directory_path, remove=False):
    if remove and os.path.exists(directory_path):
        try:
            shutil.rmtree(directory_path)
            pathlib.Path(directory_path).mkdir(parents=True, exist_ok=True)
            # os.mkdir(directory_path)
        except:
            print("Could not remove directory : ", directory_path)
            return False
    else:
        try:
            pathlib.Path(directory_path).mkdir(parents=True, exist_ok=True)
            # os.mkdir(directory_path)
        except:
            print("Could not create directory: ", directory_path)
            return False
        
    return True

# Removes directory, if directory exists 
def remove_directory(directory_path):
    if os.path.exists(directory_path):
        try:
            shutil.rmtree(directory_path)
        except:
            print("Could not remove directory : ", directory_path)
            return False
        
    return True

def clear_directory(directory_path):
    dirs_files = os.listdir(directory_path)
    
    for item in dirs_files:
#         item_path = os.path.join(directory_path, item)
        item_path = directory_path+ item
        
        try:
            if os.path.isfile(item_path):
                os.unlink(item_path)
            elif os.path.isdir(item_path): 
                shutil.rmtree(item_path)
        except Exception as e:
            print(e)
            
    return True


def remove_empty_folders(path, removeRoot=True):
    if not os.path.isdir(path):
        return
    
    # remove empty subfolders
    files = os.listdir(path)
    
    if len(files):
        for f in files:
            fullpath = os.path.join(path, f)
            
            if os.path.isdir(fullpath):
                remove_empty_folders(fullpath)

    # if folder empty, delete it
    files = os.listdir(path)
    
    if len(files) == 0 and removeRoot:
        print("Removing empty folder:", path)
        os.rmdir(path)
        
        
def dir_file_count(directory):
    return sum([len(files) for r, d, files in os.walk(directory)])

# %%
# Removes everything except alphabetical and selected characters from name string
def name_correct(name):
    return re.sub(r'[^a-zA-Z,:]', ' ', name).title()

# %%
def get_reset_subplot_params(nrows, ncols, dpi):    
    subplot_params = {}
    subplot_params["nrows"] = nrows
    subplot_params["ncols"] = ncols

    subplot_params["figsize_col"] = subplot_params["ncols"]*2.5
    subplot_params["figsize_row"] = subplot_params["nrows"]*2.5
    subplot_params["dpi"] = dpi
    subplot_params["facecolor"] = 'w'
    subplot_params["edgecolor"] = 'k'
    subplot_params["subplot_kw"] = {'xticks': [], 'yticks': []}
    subplot_params["axes.titlesize"] = 'small'
    subplot_params["hspace"] = 0.5
    subplot_params["wspace"] = 0.3
    
    return subplot_params

def get_reset_plot_params(figsize=(15, 5), title="", xlabel ="", ylabel="", legends=[], title_fontsize = 18, label_fontsize = 14, image_file_name="", save = False, dpi=100, update_image=True):
    plot_params = {}
    
    plot_params["figsize"] = figsize
    
    plot_params["title"] = title
    
    plot_params["xlabel"] = xlabel
    plot_params["ylabel"] = ylabel
    
    plot_params["legends"] = legends 
    
    plot_params["title_fontsize"] = title_fontsize
    plot_params["axes.titlesize"] = "small"
    plot_params["label_fontsize"] = label_fontsize
    
    plot_params["image_file_name"] = image_file_name
    plot_params["save"] = save
    plot_params["update_image"] = update_image
    
    plot_params["subplot"] = None
    return plot_params

# %%
def select_image_by_category(image_dir, image_count_per_category):    
    classes = os.listdir(image_dir)
    class_count = len(classes)

    image_file_paths = {}
    
    for i in range(class_count):
        subdir_path = image_dir+"/"+classes[i]
        subdir_files = os.listdir(subdir_path)

        subdir_file_count = len(subdir_files)

        subdir_file_mem = {}
        
        subdir_file_index = -1
        
        image_file_paths[classes[i]] = []
        
        for j in range(image_count_per_category):
            while subdir_file_index in subdir_file_mem:
                subdir_file_index = random.randint(0, subdir_file_count-1)
                
            subdir_file_mem[subdir_file_index] = 1
            
            subdir_file_name = subdir_files[subdir_file_index]
            subdir_file_path = subdir_path+ "/" + subdir_file_name

            image_file_paths[classes[i]].append(subdir_file_path)
            
    return image_file_paths


def get_fig_axs(subplot_params):
    fig, axs = plt.subplots(
        nrows=subplot_params["nrows"], ncols=subplot_params["ncols"], 
        figsize=(subplot_params["figsize_col"], subplot_params["figsize_row"]),
        dpi=subplot_params["dpi"], facecolor=subplot_params["facecolor"], 
        edgecolor=subplot_params["edgecolor"], subplot_kw=subplot_params["subplot_kw"])
        
    return fig, axs
    

def plot_sample_image(image_file_paths, plot_params, subplot_params, update_image=True):
    fig, axs = get_fig_axs(subplot_params)

    plt.rcParams.update({'axes.titlesize': plot_params["axes.titlesize"]})
    plt.subplots_adjust(hspace=subplot_params["hspace"], wspace=subplot_params["wspace"])


    i=0
    for img_filepath in image_file_paths:
        img = cv2.imread(img_filepath, 1)
        plt.title(img_filepath.split("/")[-1])
        plt.subplot(subplot_params["nrows"], subplot_params["ncols"], i+1)
        plt.imshow(img)
        
        plt.xticks([])
        plt.yticks([])
        
        i=i+1
        
    if plot_params["update_image"] and os.path.exists(plot_params["image_file_name"]):
        os.remove(plot_params["image_file_name"])  
    if plot_params["save"]:
        fig.savefig(plot_params["image_file_name"], dpi=plot_params["dpi"])
        
    plt.tight_layout()
    plt.show()
    
    
def show_class_sample_images(directory, image_count_per_category=5, save=False, dpi=100, update_image=False):
    class_count = len(os.listdir(directory))
    print("Number of Class: ", class_count)
    sample_img_by_class = select_image_by_category(directory, image_count_per_category)
    for class_name in sample_img_by_class:
        plot_params = get_reset_plot_params(image_file_name="img.png", save = save, dpi=dpi, update_image=update_image)
        subplot_params = get_reset_subplot_params(nrows=1, ncols=image_count_per_category, dpi=dpi)
        print("%s%s%s"%("-"*55, name_correct(class_name), "-"*55))
        plot_sample_image(sample_img_by_class[class_name], plot_params, subplot_params)
        print("")
    print("%s%s%d%s"%("-"*55, "All Class Printed:", class_count, "-"*55))

# %%
def subdirectory_file_count(master_directory):
    subdirectories = os.listdir(master_directory)
    subdirectory_count = len(subdirectories)

    subdirectory_names = []
    subdirectory_file_counts = []

    for subdirectory in subdirectories:
        current_directory = os.path.join(master_directory, subdirectory)
        file_count = len(os.listdir(current_directory))
        subdirectory_names.append(subdirectory)
        subdirectory_file_counts.append(file_count)
    
    return subdirectory_names, subdirectory_file_counts

# show barplot
def bar_plot(x, y, plot_property):
    if plot_property['subplot']:
        plt.subplot(plot_property['subplot'])
    sns.barplot(x=x, y=y)
    plt.title(plot_property['title'], fontsize=plot_property['title_fontsize'])
    plt.xlabel(plot_property['xlabel'], fontsize=plot_property['label_fontsize'])
    plt.ylabel(plot_property['ylabel'], fontsize=plot_property['label_fontsize'])
    plt.xticks(range(len(x)), x)
    
# show bar plot for count of labels in subdirectory of a directory
def count_bar_plot(master_directory, plot_property):
    dir_name, dir_file_count = subdirectory_file_count(master_directory)
    x = [name_correct(i) for i in dir_name]
    # x = dir_name
    y = dir_file_count
    bar_plot(x, y, plot_property)
    
    
# show bar plot for count of labels in subdirectory of a training, validation, testing directory    
def show_train_val_test(training_dir, validation_dir, testing_dir, plot_property):
    plt.figure(figsize=plot_property['figsize'])
    
    title = plot_property['title']
    plot_property['title'] = title + " (Training)"
    subplot_no = plot_property['subplot'] 

    count_bar_plot(training_dir, plot_property)
    
    
    plot_property['title'] = title + " (Validation)"
    plot_property['subplot'] = subplot_no+1
    count_bar_plot(validation_dir, plot_property)
    
    
    plot_property['title'] = title + " (Testing)"
    plot_property['subplot'] = subplot_no + 2
    count_bar_plot(testing_dir, plot_property)
    
    plt.show()

# %%
# Configure input/ output directory
# Configure training, validation, testing directory

input_directory = r"data/input/chest_xray/"
output_directory = r"data/output/"

training_dir = input_directory + r"train"
validation_dir = input_directory + r"val"
testing_dir = input_directory + r"test"

figure_directory = r"data/output/figures"

figure_directory = "data/output/figures"
if not os.path.exists(figure_directory):
    os.mkdir(figure_directory)
    
    
file_name_pred_batch = figure_directory+r"/result"
file_name_pred_sample = figure_directory+r"/sample"

# %%
show_class_sample_images(training_dir, image_count_per_category=5, save=False, dpi=100, update_image=False)
# Out:
# Number of Class:  2
# -------------------------------------------------------Pneumonia-------------------------------------------------------
# -------------------------------------------------------Normal-------------------------------------------------------
# -------------------------------------------------------All Class Printed:2-------------------------------------------------------

# %%
plot_params = get_reset_plot_params()

plot_params['figsize'] = (18,4)

plot_params['title_fontsize'] = 13
plot_params['label_fontsize'] = 10

plot_params['title'] = "Number of Cases"

plot_params['subplot'] = 131

show_train_val_test(training_dir, validation_dir, testing_dir, plot_params)
classes = os.listdir(training_dir)
classes = [name_correct(i) for i in classes]

# %%
img_dims = 150
batch_size = 64

# %%
input_path = 'data/input/chest_xray/'
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory(directory=input_path+'train',
target_size = (img_dims, img_dims),
batch_size = batch_size,
class_mode = 'binary')
test_set = test_datagen.flow_from_directory(directory=input_path+'test',
target_size = (img_dims, img_dims),
batch_size = batch_size,
class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape = (img_dims, img_dims, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

model.add(Flatten())
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
input_path = 'data/input/chest_xray/'
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory(directory=input_path+'train',
target_size = (img_dims, img_dims),
batch_size = batch_size,
class_mode = 'binary')
test_set = test_datagen.flow_from_directory(directory=input_path+'test',
target_size = (img_dims, img_dims),
batch_size = batch_size,
class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
epochs = 20

hist = model.fit_generator(
           training_set, steps_per_epoch=training_set.samples // batch_size, 
           epochs=epochs, validation_data=test_set, 
           validation_steps= test_set.samples)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 81/81 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9571WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 624 batches). You may need to use the repeat() function when building your dataset.
# 81/81 [==============================] - 167s 2s/step - loss: 0.1169 - accuracy: 0.9571 - val_loss: 0.4535 - val_accuracy: 0.8942
# Epoch 2/20
# 81/81 [==============================] - 151s 2s/step - loss: 0.1263 - accuracy: 0.9515
# Epoch 3/20
# 81/81 [==============================] - 154s 2s/step - loss: 0.1253 - accuracy: 0.9468
# Epoch 4/20
# 81/81 [==============================] - 157s 2s/step - loss: 0.1060 - accuracy: 0.9587
# Epoch 5/20
# 81/81 [==============================] - 156s 2s/step - loss: 0.1153 - accuracy: 0.9550
# Epoch 6/20
# 81/81 [==============================] - 151s 2s/step - loss: 0.1131 - accuracy: 0.9585
# Epoch 7/20
# 81/81 [==============================] - 153s 2s/step - loss: 0.1101 - accuracy: 0.9581
# Epoch 8/20
# 81/81 [==============================] - 153s 2s/step - loss: 0.1067 - accuracy: 0.9623
# Epoch 9/20
# 81/81 [==============================] - 153s 2s/step - loss: 0.0985 - accuracy: 0.9600
# Epoch 10/20
# 81/81 [==============================] - 150s 2s/step - loss: 0.0883 - accuracy: 0.9660
# Epoch 11/20
# 81/81 [==============================] - 152s 2s/step - loss: 0.1003 - accuracy: 0.9625
# Epoch 12/20
# 81/81 [==============================] - 157s 2s/step - loss: 0.1038 - accuracy: 0.9594
# Epoch 13/20
# 81/81 [==============================] - 153s 2s/step - loss: 0.1086 - accuracy: 0.9614
# Epoch 14/20
# 81/81 [==============================] - 164s 2s/step - loss: 0.1040 - accuracy: 0.9602
# Epoch 15/20
# 81/81 [==============================] - 154s 2s/step - loss: 0.0990 - accuracy: 0.9610
# Epoch 16/20
# 81/81 [==============================] - 156s 2s/step - loss: 0.0919 - accuracy: 0.9666
# Epoch 17/20
# 81/81 [==============================] - 155s 2s/step - loss: 0.0998 - accuracy: 0.9594
# Epoch 18/20
# 81/81 [==============================] - 152s 2s/step - loss: 0.1050 - accuracy: 0.9627
# Epoch 19/20
# 81/81 [==============================] - 151s 2s/step - loss: 0.0905 - accuracy: 0.9688
# Epoch 20/20
# 81/81 [==============================] - 155s 2s/step - loss: 0.0838 - accuracy: 0.9688

# %%
import itertools

def Confusion_matrix(cm, classes,normalize=False,title='CONFUSION MATRIX',cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)


    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
test_data = []
test_labels = []
for cond in ['/NORMAL/', '/PNEUMONIA/']:
        for img in (os.listdir(input_path + 'test' + cond)):
            img = plt.imread(input_path+'test'+cond+img)
            img = cv2.resize(img, (img_dims, img_dims))
            img = np.dstack([img, img, img])
            img = img.astype('float32') / 255
            if cond=='/NORMAL/':
                label = 0
            elif cond=='/PNEUMONIA/':
                label = 1
            test_data.append(img)
            test_labels.append(label)
        
test_data = np.array(test_data)
test_labels = np.array(test_labels)
from sklearn.metrics import accuracy_score, confusion_matrix

preds = model.predict(test_data)


acc = accuracy_score(test_labels, np.round(preds))*100
cm = confusion_matrix(test_labels, np.round(preds))
tn, fp, fn, tp = cm.ravel()

print('\n METRICS')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(acc))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))
print()
print()
Confusion_matrix(cm, classes=['NORMAL', 'PNEMONIA'])
print('Train acc: {}'.format(np.round((hist.history['accuracy'][-1])*100, 2)))

print()
print()
print(classification_report(test_labels, np.round(preds), target_names=['normal','pnemonia']))
# Out:
#  METRICS
# Accuracy: 90.86538461538461%
# Precision: 87.75510204081633%
# Recall: 99.23076923076923%
# F1-score: 93.14079422382672
#
#
# Train acc: 96.88
#
#
#               precision    recall  f1-score   support
#
#       normal       0.98      0.77      0.86       234
#     pnemonia       0.88      0.99      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.93      0.88      0.90       624
# weighted avg       0.92      0.91      0.91       624

# %%
test = plt.imread('data/input/chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg')
test = cv2.resize(img, (img_dims, img_dims))
test = np.dstack([img, img, img])
test = img.astype('float32') / 255
result = model.predict(np.expand_dims(image.img_to_array(img), axis = 0))  

if result[0][0] > 0.5:
  prediction = 'Pnuemonia'
else:
  prediction = 'Normal'
  
print(prediction)
# Out:
# Pnuemonia
